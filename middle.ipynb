# %% [markdown]
# <a href="https://colab.research.google.com/github/mr-44-bs/middle-don/blob/main/middle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import IPython.display
# !pip install pydub
from pydub import AudioSegment
import glob
import random

# %%
used_list=[]

# %%
dir_path = '/content/gdrive/My Drive/Colab Notebooks/music/*.m4a'
m4a_files = glob.glob(dir_path)
new_data = random.choice(m4a_files)
#print(new_data)
#ここまではできてる
sourceAudio = AudioSegment.from_file(new_data, "m4a")
#print("duration(sec): {}".format(sourceAudio.duration_seconds))

final = sourceAudio.duration_seconds
start = random.randint(0, int(sourceAudio.duration_seconds)-2)
next_start = random.randint(0, int(sourceAudio.duration_seconds)-2)
#print(int(sourceAudio.duration_seconds))
end = start+2
next_end = next_start+2

print(start)
processedAudio = sourceAudio[start*1000:end*1000]
next_processedAudio = sourceAudio[next_start*1000:next_end*1000]
answerMusic = sourceAudio[:10*1000]

print("問題")
IPython.display.display(processedAudio)
print("ヒント")
IPython.display.display(next_processedAudio)
print("答え")
IPython.display.display(answerMusic)

m4a_files.remove(new_data)  #removeできてる

used_list.append(new_data)

print(used_list)
# Out:
# 35
# 問題
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
# ヒント
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
# 答え
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
# ...
